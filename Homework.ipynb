# %% [markdown]
# Данный датасет включает описания 4392 компаний, торговавшихся на Нью-Йоркской фондовой бирже. Каждая компания представлена 200+ различными техническими показателями. Задача заключается в компаний на два класса - одобренные к покупке и не одобренные к покупке. Описание наиболее важных по ряду мнений инвесторов признаков представленно ниже: </br>
# **Revenue**  - доход </br>
# **Revenue Growth** - прирост дохода </br>
# **Cost of Revenue** - производственные расходы </br>
# **Gross Profit** - валовая(без ндс) прибыль  </br>
# **R&D Expenses** - расходы на инновации </br>
# **SG&A Expense**- косвенные расходы
# **Operating Expenses** - текущие расходы </br>
# **Operating Income** - текущие доходы </br>
# **Interest Expense**- процентные расходы </br>
# **Earnings before Tax** - прибыль до налогообложения </br>
# **Income Tax Expense** - расходы по налогу на прибыль </br>
# **Net Income** - чистая прибыль </br>
# **Preferred Dividends**- дивиденды на "золотые" акции </br>
# **Dividend per Share** - дивиденды на акцию </br>
# **Gross Margin** - валовая рентабельность </br>
# **EBITDA Margin** - доля выручки компании до уплаты процентов, налогов и вычета амортизации </br>
# **EBIT Margin** - отношение операционной прибыли к чистому объему продаж </br>
# **Profit Margin** - процент прибыли от общей выручки </br>
# **Free Cash Flow margin** - поток свободных денег </br>
# **EBITDA** -объём прибыли до вычета расходов по выплате процентов, налогов, износа и начисленной амортизации </br>
# **EBIT** - прибыль до вычета процентов и налогов </br>
# **Consolidated Income** - суммарный доход </br>
# **Net Profit Margin** - отношение чистой прибыли к суммарной выручке компании </br>
# **Cash and cash equivalents** - общий запас денег и денежного эквивалента </br>
# **Short-term investments** - объем краткосрочных инвестиций </br>
# **Cash and short-term investments** - общий обьем денежной массы и краткосрочных инвестиций </br>
# **Receivables** - задолженность </br>
# **Inventories** - доступные активы </br>
# **Total current assets** - общее число активов в обороте </br>
# **Goodwill and Intangible Assets** - лояльность клиентов и узнаваемость бренда </br>
# **Long-term investments** - обьем долгосрочных инвестиций </br>
# **Tax assets** - налоговые активы </br>
# **Total non-current assets** - общие необоротные активы </br>
# **Total assets** - общие активы </br>
# **Payables** - кредиторская задолженность </br>
# **Short-term debt** - задолженность по краткосрочным инвестициям </br>
# **Total current liabilities** - общие текущие обязательства </br>
# **Long-term debt** - задолженность по долгосрочным активам </br>
# **Total debt** - общий долг </br>
# **Deferred revenue** - ожидамые будущие доходы </br>
# **Tax Liabilities** - налоговые обязательства </br>
# **Deposit Liabilities** - обязательства по депозитам </br>
# **Total non-current liabilities** - общие догосрочные обязательства </br>
# **Total liabilities** - общие обязательства </br>
# **Other comprehensive income** - прочий совокупный доход </br>
# **Retained earnings (deficit)** - дефицит нераспределенной прибыли </br>
# **Total shareholders equity** - общий акционерный капитал </br>
# **Investments** - обьем инвестиций </br>
# **Weighted Average Shares Growth** - средневзвешенный рост акций </br>
# **Weighted Average Shares Diluted Growth** - средневзвешенный рост "разведенных" акций </br>
# **Dividends per Share Growth** - рост дивидендов на акцию </br>
# **Operating Cash Flow growth** - рост потока операционных издержек </br>
# **Free Cash Flow growth** - рост дпотока доступных денег </br>
# **10Y Revenue Growth (per Share)**- рост выручки за 10 лет (на акцию) </br>
# **5Y Revenue Growth (per Share)** - рост выручки за 5 лет (на акцию) </br>
# **3Y Revenue Growth (per Share)** - рост выручки за 3 года (на акцию) </br>
# **10Y Operating CF Growth (per Share)** - рост операционной прибыли за 10 лет (на акцию) </br>
# **5Y Operating CF Growth (per Share)** - рост операционной прибыли за 5 лет (на акцию) </br>
# **3Y Operating CF Growth (per Share)** - рост операционной прибыли за 3 года (на акцию) </br>
# **10Y Net Income Growth (per Share)**-
# рост чистой прибыли за 10 лет (на акцию) </br>
# **5Y Net Income Growth (per Share)**-
# рост чистой прибыли за 5 лет (на акцию) </br>
# **3Y Net Income Growth (per Share)** -
# рост чистой прибыли за 3 года (на акцию) </br>
# **10Y Shareholders Equity Growth (per Share)**-
# рост акционерного капитала за 10 лет (на акцию) </br>
# **5Y Shareholders Equity Growth (per Share)** -
# рост акционерного капитала за 5 лет (на акцию) </br>
# **3Y Shareholders Equity Growth (per Share)** - рост акционерного капитала за 3 года (на акцию) </br>
# **10Y Dividend per Share Growth (per Share)** - рост дивидендов на акции за 10 лет </br>
# **5Y Dividend per Share Growth (per Share)** - рост дивидендов на акции за 5 лет </br>
# **3Y Dividend per Share Growth (per Share)** - рост дивидендов на акции за 3 года </br>
# **Receivables growth** - рост дебиторской задолженности </br>
# **Inventory Growth** - рост доступных активов </br>
# **Asset Growth** - рост стоимости активов </br>
# **Book Value per Share Growt**h - балансовая стоимость одной акции </br>
# **Debt Growth** - рост общего долга </br>
# **R&D Expense Growth** - рост инновационных расходов </br>
# **SG&A Expenses Growth** - рост косвенных расходов  </br>
# **Sector** - сектор в котором компания осуществляет деятельность( энергетика, IT и т д) </br>
# **Class** - класс одобряемости покупки

# %% [markdown]
# 1.
# Импорт необходимых библиотек и загрузка данных с google-диска

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
drive.mount('/content/gdrive')
data_path = '/content/gdrive/MyDrive/CSV/2018_Financial_Data.csv'
data = pd.read_csv(data_path)
data = data.drop(['Unnamed: 0'], axis=1)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# 2. Визуализация данных (для лучшей читаемости я прилагаю только корреляционную матрицу на важнейшие признаки, однако также присутствует код и для пострания общей матрицы корреляции)

# %%
short_data = data[['Revenue Growth','Cost of Revenue','Gross Profit','R&D Expenses','SG&A Expense','Operating Expenses','Operating Income',
'Interest Expense',
'Earnings before Tax',
'Income Tax Expense',
'Net Income',
'Preferred Dividends',
'Dividend per Share',
'Gross Margin',
'EBITDA Margin',
'EBIT Margin',
'Profit Margin',
'Free Cash Flow margin',
'EBITDA' ,
'EBIT',
'Consolidated Income',
'Net Profit Margin']]
short_coor = short_data.corr()
plt.subplots(figsize=(12, 10))
sns.heatmap(short_coor, square=True, annot=False, vmin = -1, vmax = 1, cmap='coolwarm')
pass

# %% [markdown]
# По матрице можно отследить высокую корреляцию между рядом показателей прибыли и различных стоящимхся на ее основе показателей, что не удивительно. В остальном неожиданных корреляций не наблюдается

# %% [markdown]
# Код для просмотра общей матрицы корреляции

# %%
#corr = data.corr()
#corr.style.background_gradient(cmap='bwr')

# %% [markdown]
# Числовые характеристики по категориальным признакам:

# %%
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
num = data[numerical_columns]
pd.set_option('display.max_columns', None)
num.describe()
# Out:
#             Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# count  4.346000e+03     4253.000000     4.207000e+03  4.328000e+03
# mean   5.119287e+09        3.455278     3.144946e+09  2.043954e+09
# std    2.049504e+10      195.504906     1.508813e+10  7.682369e+09
# min   -6.894100e+07       -3.461500    -2.669055e+09 -1.818220e+09
# 25%    6.501425e+07        0.000000     3.415500e+06  3.618903e+07
# 50%    4.982640e+08        0.074900     1.741180e+08  2.219470e+08
# 75%    2.457878e+09        0.188500     1.297814e+09  9.767015e+08
# max    5.003430e+11    12739.000000     3.733960e+11  1.269470e+11
#
#        R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# count  4.155000e+03  4.226000e+03        4.208000e+03      4.357000e+03
# mean   1.180176e+08  9.005022e+08        1.435546e+09      6.541207e+08
# std    9.330891e+08  3.661116e+09        5.529831e+09      2.969341e+09
# min   -1.042000e+08 -1.401594e+08       -4.280000e+09     -1.455700e+10
# ...

# %% [markdown]
# По данным о среднем, разбросе а также минимуме и максимуме можно предположить наличие выбросов, используя метод межквартильного диапазона, позже удалим их:

# %% [markdown]
# Закодируем категориальный признак используя встроенный в scikit-learn модуль

# %%
ord_enc = OrdinalEncoder()
data["Sector"] = ord_enc.fit_transform(data[["Sector"]])

# %% [markdown]
# Удалим выбросы из колонок используя метод межквартильного интервала

# %%
Q1 = data.quantile(q=.25)
Q3 = data.quantile(q=.75)
IQR = data.apply(stats.iqr)
num_data_clean = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]
num_data_clean.shape
# Out:
# (4119, 224)

# %% [markdown]
# 4. Определим наличие незаполненных значений

# %%
columns_with_more_then_85_percents_missings =[]
for col in num_data_clean:
    pct_missing = np.mean(num_data_clean[col].isnull())
    if(pct_missing*100>0): print('{} - {}%'.format(col, (pct_missing*100)))
# Out:
# Revenue - 1.1167759164845836%
# Revenue Growth - 3.326050012138869%
# Cost of Revenue - 4.491381403253217%
# Gross Profit - 1.5537751881524642%
# R&D Expenses - 5.7052682689973295%
# SG&A Expense - 4.030104394270454%
# Operating Expenses - 4.442825928623452%
# Operating Income - 0.8497208060208788%
# Interest Expense - 4.442825928623452%
# Earnings before Tax - 1.72371934935664%
# Income Tax Expense - 3.3988832240835154%
# Net Income - Non-Controlling int - 5.996601116775917%
# Net Income - Discontinued ops - 5.996601116775917%
# Net Income - 3.641660597232338%
# Preferred Dividends - 5.996601116775917%
# Net Income Com - 2.8404952658412235%
# EPS - 1.5537751881524642%
# EPS Diluted - 1.5052197135226997%
# Weighted Average Shs Out - 1.529497450837582%
# Weighted Average Shs Out (Dil) - 4.806991988346685%
# Dividend per Share - 5.996601116775917%
# Gross Margin - 1.2381646030589948%
# EBITDA Margin - 6.749210973537266%
# EBIT Margin - 4.20004855547463%
# ...

# %% [markdown]
# Заполним пропущенные значения используя среднее по каждому столбцу

# %%
num_data_clean = num_data_clean.fillna(num_data_clean.mean())
columns_with_more_then_85_percents_missings =[]
for col in num_data_clean:
    pct_missing = np.mean(num_data_clean[col].isnull())
    if(pct_missing*100>0): print('{} - {}%'.format(col, (pct_missing*100)))

# %% [markdown]
# Применим к значениям нормализацию средним

# %%
def normalize(df):
    result = df.copy()
    max_value = df.max()
    min_value = df.min()
    result = (df - min_value) / (max_value - min_value)
    return result
num_data_clean.apply(lambda x: x if np.std(x) == 0 else normalize(x))

# %% [markdown]
# Разделим данные на тренировочные и тестовые

# %%
X, y = num_data_clean.drop(['Class'], axis=1), num_data_clean['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.67, 
                                                    random_state=42)

# %% [markdown]
# Построим классификатор "К ближайших соседей" при этом проэксперементируем с оптимальным числом классов

# %%
accuracy_list_train = []
accuracy_list_test = []
for i in range(1, 45):
    KNN = KNeighborsClassifier(n_neighbors=i)
    KNN.fit(X_train, y_train)
    
    accuracy_train = round(KNN.score(X_train, y_train)*100, 4)
    accuracy_list_train.append(accuracy_train)
    
    accuracy_test = round(KNN.score(X_test, y_test)*100, 4)
    accuracy_list_test.append(accuracy_test)

# %% [markdown]
# Построим график средней точности на обучающей выборке

# %%
k = np.arange(1, 45)
plt.figure(figsize=(12, 6))
plt.plot(k, accuracy_list_train, 'red')
plt.xlabel('k')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
plt.grid(which='major')
plt.ylabel('Accuracy on train, %')
# Out:
# [100.0, 83.3273, 82.2762, 79.7753, 79.5578, 78.2167, 77.7093, 76.8032, 76.1145, 75.4621, 75.7883, 75.4621, 75.4984, 75.3534, 75.2084, 75.5709, 75.4259, 74.8097, 74.4473, 74.4835, 74.6647, 74.5922, 74.6647, 74.5922, 74.701, 74.9184, 74.3385, 74.3023, 74.3385, 74.266, 74.1573, 74.2298, 74.0486, 74.1573, 73.5411, 73.8311, 73.6861, 73.9761, 73.8311, 73.7586, 73.7224, 73.3599, 73.1787, 73.1787]

# %% [markdown]
# Построим график средней точности на тестовой выборке

# %%
k = np.arange(1, 45)
plt.figure(figsize=(12, 6))
plt.plot(k, accuracy_list_test, 'blue')
plt.xlabel('k')
plt.xticks(np.arange(min(k), max(k)+1, 1.0))
plt.grid(which='major')
plt.ylabel('Accuracy on test, %')
# Out:
# Text(0, 0.5, 'Accuracy on test, %')

# %% [markdown]
# Нетрудно определить что оптимальным числом классов будет 31. Построим классификатор на этом числе классов и оценим его матрицу ошибок а также взвешенную f1 оценку

# %%
knn = KNeighborsClassifier(n_neighbors = 31)
knn.fit(X_train, y_train)
y_test_predict = knn.predict(X_test)
print(confusion_matrix(y_test, y_test_predict))
from sklearn.metrics import f1_score
f1_score(y_test, y_test_predict, average='weighted')
# Out:
# [[144 267]
#  [102 847]]
# 0.7054564751816569

# %% [markdown]
# Результат можно интепретировать как 70% точность классификатора, что является неплохим но вполне ожидаемым результатом для такого достаточно простого классификатора. Для сравнения применим классификатор RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=8, random_state=0)
clf.fit(X, y)
y_test_predict = clf.predict(X_test)
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
from sklearn.metrics import f1_score
f1_score(y_test, y_test_predict, average='weighted')
# Out:
# [[391  20]
#  [  0 949]]
# 0.9851874255354068

# %% [markdown]
# Разница видна невооруженным взглядом, RandomFoest дает почти 100% точность

# %% [markdown]
# 10.
# В рамках данного домашнего задания была рассмотрена задача классификации компаний на основании их финансовых характеристик на одобряемые к покупке и неодобряемые. Поскольку признаки имели пропущенные значения, они были замененны средним. Так как присутствовали выбросы и наблюдался сильный разброс, выбросы были отброшены, и примененна нормализация.
# При обучении алгоритмом k-ближайших соседей лучший результат достигается при k = 31, f1-score на тестовой выборке равна 0.7054564751816569 что является хорошим но ожидаемым результатом. Сравнивая с RandomForestClassifier, можно отметить, что он показывают результаты гораздо лучше, чем KNN.
#
# Таким образом, исходя из сказанного выше, можно сделать вывод, что предобработка данных была выполнена успешна, что позволило успешно решить задачу классификации.
